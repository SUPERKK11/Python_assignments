# %% [markdown]
# 1]wap to print the middle value of a list only if it is string

# %%
list1=eval(input("enter the list: "))
a=len(list1)
if type(list1[a//2])== str:
    print("There is the string value")
# Out:
# There is the string value

# %% [markdown]
# 2] wap to check the ch is vowel or consonant

# %%
ch=input("Enter the string value: ")
if len(ch) == 1:
    if ch in "aeiouAEIOU":
        print("The string value is a vowel")
    else:
        print("The string value is a consonant")
# Out:
# The string value is a consonant

# %% [markdown]
# 3]wap to find the greatest of 4 numbers

# %%
#using nested if
num1=int(input("Enter the number: "))
num2=int(input("Enter the number: "))
num3=int(input("Enter the number: "))
num4=int(input("Enter the number: "))
if num1>num2 :
    if num1>num3:
        if num1>num4:
            print(f"goat is {num1}")
        else:
            print(f"goat is {num4}")
    else:
        if num3>num4:
            print(f"goat is {num3}")
        else:
            print(f"goat is {num4}")
else:
    if num2>num3:
        if num2>num4:
            print(f"goat is {num2}")
        else:
            print(f"goat is {num4}")
    else:
        if num3>num4:
            print(f"goat is {num3}")
        else:
            print(f"goat is {num4}")
# Out:
# goat is 11

# %%
num=int(input("Enter the number: "))
num2=int(input("Enter the number: "))
num3=int(input("Enter the number: "))
num4=int(input("Enter the number: "))
if num>num2 and num>num3 and num>num4:
    print("The greatest number is: ",num)
elif num2>num and num2>num3 and num2>num4:
    print("The greatest number is: ",num2)
elif num3>num and num3>num2 and num3>num4:
    print("The greatest number is: ",num3)
else:
    print("The greatest number is: ",num4)
# Out:
# The greatest number is:  4

# %% [markdown]
# 4] wap to print value only if the lenght of value is even

# %%
value=eval(input("Enter the number: "))
if type(value) in [str,list,tuple,set,dict]:
    len_value=len(value)
if len_value%2==0:
    print(value)
else: 
    print(value)
# Out:
# 1

# %% [markdown]
# 5] wap to display the last element of string of the string is palindrome and the first character is vowel

# %%
input_string=eval(input("enter the string "))
str(input_string)
if input_string == input_string[::-1] and input_string[0] in "aeiouAEIOU":
        print(input_string[-1])
# Out:
# a

# %% [markdown]
# 6]wap to print the reversed of the string if the first ch is vowel and last is consonants?

# %%
input_string=input("enter the string : ")
if input_string[0] in "aeiouAEIOU" and input_string[-1] not in "aeiouAEIOU" and len(input_string)%2 != 0 :
    print(input_string[::-1])
# Out:
# huoia

# %% [markdown]
# 7] wap to print second greatest number

# %%
num1=int(input("Enter the number: "))
num2=int(input("Enter the number: "))
num3=int(input("Enter the number: "))
num4=int(input("Enter the number: "))
if num1>num2 and num1>num3 and num1>num4:
        print("The greatest number is: ",num1)
    if num2>num3 and num2>num4:
        print(f"second greatest value is {num2}")
    elif num3>num2 and num3>num4:
        print(f"second greatest value is {num3}")
    elif num4>num2 and num4>num3:
        print(f"second greatest value is {num4}")
    else:
        print("all the values are same ")
    
elif num2>num1 and num2>num3 and num2>num4:
    print("The greatest number is: ",num2)
    if num1>num3 and num1>num4:
        print(f"second greatest value is {num1}")
    elif num3>num1 and num3>num4:
        print(f"second greatest value is {num3}")
    elif num4>num1 and num4>num3:
        print(f"second greatest value is {num4}")
    else:
        print("all the values are same")
    
elif num3>num1 and num3>num2 and num3>num4:
    print("The greatest number is: ",num3)
    if num2>num1 and num2>num4:
        print(f"second greatest value is {num2}")
    elif num1>num2 and num1>num4:
        print(f"second greatest value is {num1}")
    elif num4>num2 and num4>num1:
        print(f"second greatest value is {num4}")
elif num4>num1 and num4>num2 and num4>num3:
        print("The greatest number is: ",num4)
        if num1>num2 and num1>num3:
            print(f"second greatest value is {num1}")
        elif num2>num1 and num2>num3:
            print(f"second greatest value is {num2}")
        elif num3>num1 and num3>num2:
            print(f"second greatest value is {num3}")
        else:
            print("all the values are same")
else:
    print("all the values are same")
# Out:
# all the values are same

# %% [markdown]
# 37] print the smallest value using nested if

# %%
#using nested if
num1=int(input("Enter the number: "))
num2=int(input("Enter the number: "))
num3=int(input("Enter the number: "))
num4=int(input("Enter the number: "))
if num1<num2 :
    if num1<num3:
        if num1<num4:
            print(f"messi is {num1}")
        else:
            print(f"messi is {num4}")
    else:
        if num3<num4:
            print(f"messi is {num3}")
        else:
            print(f"messi is {num4}")
else:
    if num2<num3:
        if num2<num4:
            print(f"messi is {num2}")
        else:
            print(f"messi is {num4}")
    else:
        if num3<num4:
            print(f"messi is {num3}")
        else:
            print(f"messi is {num4}")

# %% [markdown]
# 38] wap to print middle character of the given string only if it is UPPer

# %%
ch=input("enter the string")
if "A"<=ch[len(ch)//2]<="Z":
    print(ch[len(ch)//2])
# Out:
# L
