# %% [markdown]
# # global Variable

# %% [markdown]
# The variable that we can access from anywhere in the program we called it global variable

# %% [markdown]
# # Local Variable

# %% [markdown]
# The variable that we can access inside method or function is known as Local variable
