# %% [markdown]
# 1] WAP to check whether the character is a vowel or not.

# %%
enter_input=str(input("enter the character "))
if enter_input == "A" and "E" and "I" and "O" and "U" and "a" and  "i" and  "o" and "u" and "e":
    print("vowel")
else:
    print("not")
# Out:
# not

# %% [markdown]
# 2] WAP to print the ASCII value of a character only if it is uppercase.

# %%
enter_input=str(input("enter the character "))
if "A"<= enter_input <="Z":
    print("Upper case")
else:
    print("lower")
# Out:
# lower

# %%
enter_input=str(input("enter the character "))
if enter_input.isupper():
    print("Upper case")
else:
    print("lower")
# Out:
# lower

# %% [markdown]
# 3]WAP to print the cube of a number only if it is divisible by 9 or 6.

# %%
enter_input=int(input("enter the number "))
if (enter_input % 9 == 0 and enter_input % 6 == 0):
    print(enter_input**3)

# %% [markdown]
# 4] WAP to check whether the given integer is a 3-digit number.

# %%
enter_input=int(input("enter the number"))
if enter_input >=100 and enter_input<=999:
    print("3 digit number")
# Out:
# 3 digit number

# %% [markdown]
# 5]WAP to check whether the last digit of a given number is 5.

# %%
enter_input=int(input("enter the number"))
if enter_input % 5 == 0 and enter_input % 10 != 0:
    print("last digit is 5")
# Out:
# last digit is 5

# %% [markdown]
# 6]WAP to check whether the given data is float.

# %%
enter_input=float(input("enter the number"))
if enter_input.is_integer():
    pass
else:
    print("float")
# Out:
# float

# %%
enter_input=input("enter the number ")# this assumes string therfore 
a=isinstance(enter_input,float)
print(a)
if a:
    print("float")
# Out:
# True
# float

# %%
#logic
dir(float()) #first i checked whether there esxists some function
a=float(2.2)
a.is_integer()# and then found this function
# Out:
# False

# %% [markdown]
# 7] WAP to check whether the data is a single-value data type.

# %%
x = 1 
if isinstance(x, (float,int,complex,bool)):
    print("SVD")
# Out:
# SVD

# %% [markdown]
# 8]WAP to check whether the given character is a digit.
